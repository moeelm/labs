# %%
# %matplotlib inline

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Matplotlib:Your new best friend

# %% [markdown]
# $$ y=mx+b $$

# %% [markdown]
# $$ \Delta x$$

# %%
import matplotlib.pyplot as plt
plt.plot ([1,2,3,4],'c--*',label='jesus white hairs' )
plt.plot ([5,6,7,8], 'r--^',label='time that goes by' ) 
plt.ylabel ('some numbers')
plt.xlabel ('Other numbers')
plt.title ('graph of numbers')
plt.legend ()
plt.show ()

# %%
import matplotlib.pyplot as plt
plt.plot ([1,2,3,4,5],[5,6,7,8,9],'r--o', label= 'jesus')
plt.plot ([5,4,3,2,1],[1,2,3,4,5,],'c--^', label= 'moe')
plt.ylabel ('work')
plt.xlabel ('energy')
plt.title ('work per energy')
plt.legend ()
plt.show ()

# %%
import numpy as np
from scipy.optimize import curve_fit

def model(a,b,x):
    return a*x+b

x = np.random.uniform(0.,100.,100)
y = 3. * x+2. + np.random.normal(0.,10., 100)

params, maytte= curve_fit(model, x , y)
plt.plot(x,y,'r
         
         
         .')
plt.xlabel ('aha')
plt.ylabel ('hah')
plt.title ('Maytte')
# Out:
#   File "<ipython-input-2-4322e5663916>", line 11
#     plt.plot(x,y,'r
#                    ^
# SyntaxError: EOL while scanning string literal

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
x=  np.random.uniform(0., 100.,100)
y= 3.* x +2. + np.random.normal (0., 10, 100)

def line(x, a, b):
    return a*x+ b
xm= np.linspace(0.,100., 100)

lin_vars, crap= curve_fit(line, x, y)
plt.plot(line(xm, lin_vars[0], lin_vars[1]), 'r-')
plt.plot(x, y, '.')
